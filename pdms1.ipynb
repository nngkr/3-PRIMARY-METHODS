# %%
import pandas as pd
import numpy as np
data=pd.read_csv(r"D:\PYTHON\tp1\Prices%20house.csv")
df=pd.DataFrame(data)
df
# Out:
#            Size  Number of rooms  Location  Distance of the center  \
# 0      0.935726         0.921034  0.050417                0.173085
# 1      0.945854         0.084170  0.211671                0.080723
# 2      0.425973         0.190178  0.221490                0.443040
# 3      0.599944         0.237729  0.584219                0.387131
# 4      0.293112         0.322832  0.065941                0.615047
# ...         ...              ...       ...                     ...
# 19995  0.233252         0.767280  0.617955                0.872762
# 19996  0.761047         0.412396  0.923288                0.944881
# 19997  0.831551         0.199999  0.744946                0.971285
# 19998  0.839408         0.216327  0.528366                0.412535
# 19999  0.944656         0.823829  0.805750                0.749896
#
#        Years of construction        Date  \
# 0                   0.139500  12/09/1995
# 1                   0.980385  17/06/2015
# ...

# %% [markdown]
# BUILD QUALITY WITH PRICE

# %%
df['build_price']=df['Price final']/df['Build quality']
df
# Out:
#            Size  Number of rooms  Location  Distance of the center  \
# 0      0.935726         0.921034  0.050417                0.173085
# 1      0.945854         0.084170  0.211671                0.080723
# 2      0.425973         0.190178  0.221490                0.443040
# 3      0.599944         0.237729  0.584219                0.387131
# 4      0.293112         0.322832  0.065941                0.615047
# ...         ...              ...       ...                     ...
# 19995  0.233252         0.767280  0.617955                0.872762
# 19996  0.761047         0.412396  0.923288                0.944881
# 19997  0.831551         0.199999  0.744946                0.971285
# 19998  0.839408         0.216327  0.528366                0.412535
# 19999  0.944656         0.823829  0.805750                0.749896
#
#        Years of construction        Date  \
# 0                   0.139500  12/09/1995
# 1                   0.980385  17/06/2015
# ...

# %%
df['Date']=pd.to_datetime(df['Date'],format='%d/%m/%Y')
df['month']=df['Date'].dt.month
df['year']=df['Date'].dt.year
df
# Out:
#            Size  Number of rooms  Location  Distance of the center  \
# 0      0.935726         0.921034  0.050417                0.173085
# 1      0.945854         0.084170  0.211671                0.080723
# 2      0.425973         0.190178  0.221490                0.443040
# 3      0.599944         0.237729  0.584219                0.387131
# 4      0.293112         0.322832  0.065941                0.615047
# ...         ...              ...       ...                     ...
# 19995  0.233252         0.767280  0.617955                0.872762
# 19996  0.761047         0.412396  0.923288                0.944881
# 19997  0.831551         0.199999  0.744946                0.971285
# 19998  0.839408         0.216327  0.528366                0.412535
# 19999  0.944656         0.823829  0.805750                0.749896
#
#        Years of construction       Date  \
# 0                   0.139500 1995-09-12
# 1                   0.980385 2015-06-17
# ...

# %%
df['ytob']=np.where(df['year']>=2000,1,0)
df
# Out:
#            Size  Number of rooms  Location  Distance of the center  \
# 0      0.935726         0.921034  0.050417                0.173085
# 1      0.945854         0.084170  0.211671                0.080723
# 2      0.425973         0.190178  0.221490                0.443040
# 3      0.599944         0.237729  0.584219                0.387131
# 4      0.293112         0.322832  0.065941                0.615047
# ...         ...              ...       ...                     ...
# 19995  0.233252         0.767280  0.617955                0.872762
# 19996  0.761047         0.412396  0.923288                0.944881
# 19997  0.831551         0.199999  0.744946                0.971285
# 19998  0.839408         0.216327  0.528366                0.412535
# 19999  0.944656         0.823829  0.805750                0.749896
#
#        Years of construction       Date  \
# 0                   0.139500 1995-09-12
# 1                   0.980385 2015-06-17
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0
